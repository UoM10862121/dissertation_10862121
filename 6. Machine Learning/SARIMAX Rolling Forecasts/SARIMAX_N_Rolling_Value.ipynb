# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.29.36)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import json
from datetime import timedelta
from sklearn.ensemble import RandomForestRegressor
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima
import pickle
import itertools
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pmdarima as pm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
merged_n = pd.read_csv(r'/content/drive/MyDrive/Dissertation_10862121/merged_n.csv')

# %%
merged_n['GMT'] = pd.to_datetime(merged_n['GMT'])
merged_n['Date'] = pd.to_datetime(merged_n['Date'])
merged_n.set_index('GMT', inplace=True)

# %%
merged_n
# Out:
#                      Total Household Consumption (N)       Date      Time  \
# GMT
# 2013-01-01 00:00:00                      1657.483601 2013-01-01  00:00:00
# 2013-01-01 01:00:00                      1422.045237 2013-01-01  01:00:00
# 2013-01-01 02:00:00                      1200.551314 2013-01-01  02:00:00
# 2013-01-01 03:00:00                      1061.568405 2013-01-01  03:00:00
# 2013-01-01 04:00:00                      1000.474013 2013-01-01  04:00:00
# ...                                              ...        ...       ...
# 2013-12-31 19:00:00                      2979.858073 2013-12-31  19:00:00
# 2013-12-31 20:00:00                      2700.407931 2013-12-31  20:00:00
# 2013-12-31 21:00:00                      2447.194261 2013-12-31  21:00:00
# 2013-12-31 22:00:00                      2232.695632 2013-12-31  22:00:00
# 2013-12-31 23:00:00                      2001.119964 2013-12-31  23:00:00
#
#                      Year  Month  Day  Hour  DayOfWeek  IsHoliday  \
# GMT
# 2013-01-01 00:00:00  2013      1    1     0          1       True
# 2013-01-01 01:00:00  2013      1    1     1          1       True
# 2013-01-01 02:00:00  2013      1    1     2          1       True
# 2013-01-01 03:00:00  2013      1    1     3          1       True
# 2013-01-01 04:00:00  2013      1    1     4          1       True
# ...                   ...    ...  ...   ...        ...        ...
# 2013-12-31 19:00:00  2013     12   31    19          1      False
# 2013-12-31 20:00:00  2013     12   31    20          1      False
# 2013-12-31 21:00:00  2013     12   31    21          1      False
# 2013-12-31 22:00:00  2013     12   31    22          1      False
# 2013-12-31 23:00:00  2013     12   31    23          1      False
#
#                      Hourly Global Radiation (KJ/m2)  \
# GMT
# 2013-01-01 00:00:00                              0.0
# 2013-01-01 01:00:00                              0.0
# 2013-01-01 02:00:00                              0.0
# 2013-01-01 03:00:00                              0.0
# 2013-01-01 04:00:00                              0.0
# ...                                              ...
# 2013-12-31 19:00:00                              0.0
# 2013-12-31 20:00:00                              0.0
# 2013-12-31 21:00:00                              0.0
# 2013-12-31 22:00:00                              0.0
# 2013-12-31 23:00:00                              0.0
#
#                      Hourly Maximum Gust (kn)  Hourly Mean Wind Direction (o)  \
# GMT
# 2013-01-01 00:00:00                      13.2                           232.0
# 2013-01-01 01:00:00                      13.6                           236.0
# 2013-01-01 02:00:00                      13.2                           246.0
# 2013-01-01 03:00:00                      18.6                           286.0
# 2013-01-01 04:00:00                      15.4                           278.0
# ...                                       ...                             ...
# 2013-12-31 19:00:00                      12.8                           192.0
# 2013-12-31 20:00:00                      13.6                           196.0
# 2013-12-31 21:00:00                      13.6                           186.0
# 2013-12-31 22:00:00                      15.2                           182.0
# 2013-12-31 23:00:00                      17.8                           190.0
#
#                      Hourly Mean Windspeed (kn)  \
# GMT
# 2013-01-01 00:00:00                         7.8
# 2013-01-01 01:00:00                         8.0
# 2013-01-01 02:00:00                         7.6
# 2013-01-01 03:00:00                         9.0
# 2013-01-01 04:00:00                         7.4
# ...                                         ...
# 2013-12-31 19:00:00                         7.8
# 2013-12-31 20:00:00                         7.4
# 2013-12-31 21:00:00                         7.6
# 2013-12-31 22:00:00                         8.4
# 2013-12-31 23:00:00                         9.2
#
#                      Hourly Pressure at Mean Sea Level (hPa)  \
# GMT
# 2013-01-01 00:00:00                                  999.400
# 2013-01-01 01:00:00                                  999.675
# 2013-01-01 02:00:00                                  999.975
# 2013-01-01 03:00:00                                 1000.725
# 2013-01-01 04:00:00                                 1001.300
# ...                                                      ...
# 2013-12-31 19:00:00                                 1002.900
# 2013-12-31 20:00:00                                 1003.175
# 2013-12-31 21:00:00                                 1003.450
# 2013-12-31 22:00:00                                 1002.925
# 2013-12-31 23:00:00                                 1002.725
#
#                      Hourly Rainfall Total (mm)  Hourly Relative Humidity (%)  \
# GMT
# 2013-01-01 00:00:00                        0.00                     92.085714
# 2013-01-01 01:00:00                        0.00                     91.042857
# 2013-01-01 02:00:00                        0.20                     92.685714
# 2013-01-01 03:00:00                        0.96                     89.871429
# 2013-01-01 04:00:00                        0.08                     88.585714
# ...                                         ...                           ...
# 2013-12-31 19:00:00                        0.00                     85.385714
# 2013-12-31 20:00:00                        0.00                     84.442857
# 2013-12-31 21:00:00                        0.00                     83.257143
# 2013-12-31 22:00:00                        0.00                     88.628571
# 2013-12-31 23:00:00                        0.00                     88.314286
#
#                      Hourly Snow Depth (cm)  Hourly Temperature (C)  \
# GMT
# 2013-01-01 00:00:00                     0.0                8.914286
# 2013-01-01 01:00:00                     0.0                8.785714
# 2013-01-01 02:00:00                     0.0                8.514286
# 2013-01-01 03:00:00                     0.0                7.285714
# 2013-01-01 04:00:00                     0.0                6.700000
# ...                                     ...                     ...
# 2013-12-31 19:00:00                     0.0                5.942857
# 2013-12-31 20:00:00                     0.0                5.442857
# 2013-12-31 21:00:00                     0.0                5.414286
# 2013-12-31 22:00:00                     0.0                5.971429
# 2013-12-31 23:00:00                     0.0                7.057143
#
#                      Hourly Total Cloud Cover (oktas)\n  \
# GMT
# 2013-01-01 00:00:00                            8.000000
# 2013-01-01 01:00:00                            8.000000
# 2013-01-01 02:00:00                            8.000000
# 2013-01-01 03:00:00                            7.666667
# 2013-01-01 04:00:00                            4.000000
# ...                                                 ...
# 2013-12-31 19:00:00                            6.333333
# 2013-12-31 20:00:00                            1.333333
# 2013-12-31 21:00:00                            1.000000
# 2013-12-31 22:00:00                            2.333333
# 2013-12-31 23:00:00                            6.333333
#
#                      Hourly Visibility (dm)
# GMT
# 2013-01-01 00:00:00             2133.333333
# 2013-01-01 01:00:00             1766.666667
# 2013-01-01 02:00:00             1333.333333
# 2013-01-01 03:00:00             4100.000000
# 2013-01-01 04:00:00             5500.000000
# ...                                     ...
# 2013-12-31 19:00:00             3666.666667
# 2013-12-31 20:00:00             4000.000000
# 2013-12-31 21:00:00             3833.333333
# 2013-12-31 22:00:00             2266.666667
# 2013-12-31 23:00:00             2200.000000
#
# [8760 rows x 20 columns]

# %% [markdown]
# Daily Dataframe

# %%
#New DataFrame storing daily aggregated data
daily_n = merged_n.resample('D').agg({
    'Total Household Consumption (N)': 'sum',
    'Hourly Temperature (C)': 'mean',
    'Hourly Pressure at Mean Sea Level (hPa)': 'mean',
    'Hourly Global Radiation (KJ/m2)': 'mean',
    'Hourly Rainfall Total (mm)': 'mean',
    'Hourly Mean Wind Direction (o)': 'mean',
    'Hourly Mean Windspeed (kn)': 'mean',
    'Hourly Maximum Gust (kn)': 'mean',
    'Hourly Visibility (dm)': 'mean',
    'Hourly Relative Humidity (%)': 'mean',
    'Hourly Total Cloud Cover (oktas)\n': 'mean',
}).reset_index()

# %%
#Non-aggregated columns
daily_n['Date'] = daily_n['GMT'].dt.date
daily_n['Month'] = daily_n['GMT'].dt.month
daily_n['Day'] = daily_n['GMT'].dt.day
daily_n['DayOfWeek'] = daily_n['GMT'].dt.dayofweek

# %%
#Renaming the columns for the weather variables to indicate they now contain daily averages
daily_n.rename(columns={
    'Hourly Temperature (C)': 'Daily Temperature (C)',
    'Hourly Pressure at Mean Sea Level (hPa)': 'Daily Pressure at Mean Sea Level (hPa)',
    'Hourly Global Radiation (KJ/m2)': 'Daily Global Radiation (KJ/m2)',
    'Hourly Rainfall Total (mm)': 'Daily Rainfall Total (mm)',
    'Hourly Mean Wind Direction (o)': 'Daily Mean Wind Direction (o)',
    'Hourly Mean Windspeed (kn)': 'Daily Mean Windspeed (kn)',
    'Hourly Maximum Gust (kn)': 'Daily Maximum Gust (kn)',
    'Hourly Visibility (dm)': 'Daily Visibility (dm)',
    'Hourly Relative Humidity (%)': 'Daily Relative Humidity (%)',
    'Hourly Total Cloud Cover (oktas)\n': 'Daily Total Cloud Cover (oktas)'
}, inplace=True)

# %%
#Calculating 'Peak Day Value' and 'Peak Day Hour'
max_consumption_idx = merged_n.groupby(merged_n.index.date)['Total Household Consumption (N)'].idxmax()
peak_values = merged_n.loc[max_consumption_idx, 'Total Household Consumption (N)']
peak_hours = merged_n.loc[max_consumption_idx, 'Hour']

# %%
#Creating dictionaries for mapping
peak_values_dict = dict(zip(peak_values.index.date, peak_values.values))
peak_hours_dict = dict(zip(peak_hours.index.date, peak_hours.values))

#Merging 'Peak Day Value' and 'Peak Day Hour' into the daily_aggregated DataFrame
daily_n['Peak Day Value'] = daily_n['Date'].map(peak_values_dict)
daily_n['Peak Day Hour'] = daily_n['Date'].map(peak_hours_dict)

# %%
daily_n.drop(columns=['GMT'], inplace=True)

# %%
daily_n['Date'] = pd.to_datetime(daily_n['Date'])
daily_n.set_index('Date', inplace=True)

# %%
#Converting the 'IsHoliday' column in merged_n to integer type for summation
merged_n['IsHoliday'] = merged_n['IsHoliday'].astype(int)

#Grouping by 'Date' and summing the 'IsHoliday' column
daily_holidays = merged_n.groupby('Date').agg({'IsHoliday': 'sum'})

#Converting the summed values to a binary (0 or 1) indicating presence of holiday
daily_holidays['IsHoliday'] = daily_holidays['IsHoliday'].apply(lambda x: 1 if x > 0 else 0)

daily_n['IsHoliday'] = daily_n.index.map(daily_holidays['IsHoliday']).fillna(0).astype(int)

# %%
daily_n
# Out:
#             Total Household Consumption (N)  Daily Temperature (C)  \
# Date
# 2013-01-01                     48554.429048               5.991667
# 2013-01-02                     49236.824514               6.440476
# 2013-01-03                     46679.941973              10.262500
# 2013-01-04                     46521.073230               9.350595
# 2013-01-05                     48215.904865               8.830952
# ...                                     ...                    ...
# 2013-12-27                     47335.780581               8.875595
# 2013-12-28                     46416.061681               5.114881
# 2013-12-29                     48486.228501               3.575000
# 2013-12-30                     48179.443646               8.364286
# 2013-12-31                     48504.416368               7.648214
#
#             Daily Pressure at Mean Sea Level (hPa)  \
# Date
# 2013-01-01                             1007.663542
# 2013-01-02                             1023.133333
# 2013-01-03                             1032.562500
# 2013-01-04                             1037.157292
# 2013-01-05                             1035.168750
# ...                                            ...
# 2013-12-27                              987.026042
# 2013-12-28                              997.500000
# 2013-12-29                             1014.921875
# 2013-12-30                             1011.072917
# 2013-12-31                             1004.409375
#
#             Daily Global Radiation (KJ/m2)  Daily Rainfall Total (mm)  \
# Date
# 2013-01-01                      169.819444                   0.053056
# 2013-01-02                       42.569444                   0.022083
# 2013-01-03                       73.277778                   0.000000
# 2013-01-04                       76.111111                   0.001389
# 2013-01-05                       52.430556                   0.000000
# ...                                    ...                        ...
# 2013-12-27                       51.805556                   0.201111
# 2013-12-28                      139.125000                   0.000000
# 2013-12-29                      177.194444                   0.009722
# 2013-12-30                       52.722222                   0.260972
# 2013-12-31                       37.819444                   0.233194
#
#             Daily Mean Wind Direction (o)  Daily Mean Windspeed (kn)  \
# Date
# 2013-01-01                     261.166667                   8.700000
# 2013-01-02                     237.750000                   7.083333
# 2013-01-03                     257.666667                   8.525000
# 2013-01-04                     266.500000                   8.466667
# 2013-01-05                     244.916667                   6.508333
# ...                                   ...                        ...
# 2013-12-27                     213.416667                  15.400000
# 2013-12-28                     229.916667                   6.158333
# 2013-12-29                     232.000000                   6.266667
# 2013-12-30                     200.416667                  13.400000
# 2013-12-31                     182.333333                   9.208333
#
#             Daily Maximum Gust (kn)  Daily Visibility (dm)  \
# Date
# 2013-01-01                15.141667            3816.666667
# 2013-01-02                11.925000            2337.638889
# 2013-01-03                14.816667            2503.611111
# 2013-01-04                14.875000            2924.444444
# 2013-01-05                11.458333            2072.361111
# ...                             ...                    ...
# 2013-12-27                28.516667            1995.972222
# 2013-12-28                10.891667            3338.888889
# 2013-12-29                10.800000            2831.944444
# 2013-12-30                24.466667            2367.083333
# 2013-12-31                17.408333            2581.527778
#
#             Daily Relative Humidity (%)  Daily Total Cloud Cover (oktas)  \
# Date
# 2013-01-01                    81.655952                         3.097222
# 2013-01-02                    91.691667                         6.722222
# 2013-01-03                    92.282738                         7.611111
# 2013-01-04                    85.682738                         7.777778
# 2013-01-05                    92.425000                         7.041667
# ...                                 ...                              ...
# 2013-12-27                    75.789286                         5.013889
# 2013-12-28                    78.417262                         2.847222
# 2013-12-29                    84.811905                         0.916667
# 2013-12-30                    84.788095                         5.125000
# 2013-12-31                    87.792262                         6.083333
#
#             Month  Day  DayOfWeek  Peak Day Value  Peak Day Hour  IsHoliday
# Date
# 2013-01-01      1    1          1     3232.153651             18          1
# 2013-01-02      1    2          2     3272.932430             19          0
# 2013-01-03      1    3          3     3160.668542             18          0
# 2013-01-04      1    4          4     3103.807307             18          0
# 2013-01-05      1    5          5     3199.016994             18          0
# ...           ...  ...        ...             ...            ...        ...
# 2013-12-27     12   27          4     2936.761545             18          0
# 2013-12-28     12   28          5     2933.939376             18          0
# 2013-12-29     12   29          6     3083.519833             18          0
# 2013-12-30     12   30          0     3064.231161             18          0
# 2013-12-31     12   31          1     3185.078676             18          0
#
# [365 rows x 17 columns]

# %% [markdown]
# Lags (Endogenous Variables)

# %%
daily_n['lag_1_day_peak'] = daily_n['Peak Day Value'].shift(1)
daily_n['lag_2_day_peak'] = daily_n['Peak Day Value'].shift(2)
daily_n['lag_3_day_peak'] = daily_n['Peak Day Value'].shift(3)
daily_n['lag_4_day_peak'] = daily_n['Peak Day Value'].shift(4)
daily_n['lag_5_day_peak'] = daily_n['Peak Day Value'].shift(5)
daily_n['lag_6_day_peak'] = daily_n['Peak Day Value'].shift(6)
daily_n['lag_7_day_peak'] = daily_n['Peak Day Value'].shift(7)

# %%
nan_rows = daily_n[daily_n.isna().any(axis=1)]
print(nan_rows)
# Out:
#             Total Household Consumption (N)  Daily Temperature (C)  \
# Date
# 2013-01-01                     48554.429048               5.991667
# 2013-01-02                     49236.824514               6.440476
# 2013-01-03                     46679.941973              10.262500
# 2013-01-04                     46521.073230               9.350595
# 2013-01-05                     48215.904865               8.830952
# 2013-01-06                     50882.159539               7.158929
# 2013-01-07                     47973.791500               7.730952
#
#             Daily Pressure at Mean Sea Level (hPa)  \
# Date
# 2013-01-01                             1007.663542
# 2013-01-02                             1023.133333
# 2013-01-03                             1032.562500
# 2013-01-04                             1037.157292
# 2013-01-05                             1035.168750
# 2013-01-06                             1032.208333
# 2013-01-07                             1026.888542
#
#             Daily Global Radiation (KJ/m2)  Daily Rainfall Total (mm)  \
# Date
# 2013-01-01                      169.819444                   0.053056
# 2013-01-02                       42.569444                   0.022083
# 2013-01-03                       73.277778                   0.000000
# 2013-01-04                       76.111111                   0.001389
# 2013-01-05                       52.430556                   0.000000
# 2013-01-06                       52.388889                   0.008611
# 2013-01-07                       37.694444                   0.001389
#
#             Daily Mean Wind Direction (o)  Daily Mean Windspeed (kn)  \
# Date
# 2013-01-01                     261.166667                   8.700000
# 2013-01-02                     237.750000                   7.083333
# 2013-01-03                     257.666667                   8.525000
# 2013-01-04                     266.500000                   8.466667
# 2013-01-05                     244.916667                   6.508333
# 2013-01-06                     223.666667                   4.258333
# 2013-01-07                     205.166667                   6.491667
#
#             Daily Maximum Gust (kn)  Daily Visibility (dm)  \
# Date
# 2013-01-01                15.141667            3816.666667
# 2013-01-02                11.925000            2337.638889
# 2013-01-03                14.816667            2503.611111
# 2013-01-04                14.875000            2924.444444
# 2013-01-05                11.458333            2072.361111
# 2013-01-06                 7.900000             623.194444
# 2013-01-07                11.450000            1270.555556
#
#             Daily Relative Humidity (%)  ...  Peak Day Value  Peak Day Hour  \
# Date                                     ...
# 2013-01-01                    81.655952  ...     3232.153651             18
# 2013-01-02                    91.691667  ...     3272.932430             19
# 2013-01-03                    92.282738  ...     3160.668542             18
# 2013-01-04                    85.682738  ...     3103.807307             18
# 2013-01-05                    92.425000  ...     3199.016994             18
# 2013-01-06                    97.227976  ...     3355.898550             18
# 2013-01-07                    92.857143  ...     3323.770475             18
#
#             IsHoliday  lag_1_day_peak  lag_2_day_peak  lag_3_day_peak  \
# Date
# 2013-01-01          1             NaN             NaN             NaN
# 2013-01-02          0     3232.153651             NaN             NaN
# 2013-01-03          0     3272.932430     3232.153651             NaN
# 2013-01-04          0     3160.668542     3272.932430     3232.153651
# 2013-01-05          0     3103.807307     3160.668542     3272.932430
# 2013-01-06          0     3199.016994     3103.807307     3160.668542
# 2013-01-07          0     3355.898550     3199.016994     3103.807307
#
#             lag_4_day_peak  lag_5_day_peak  lag_6_day_peak  lag_7_day_peak
# Date
# 2013-01-01             NaN             NaN             NaN             NaN
# 2013-01-02             NaN             NaN             NaN             NaN
# 2013-01-03             NaN             NaN             NaN             NaN
# 2013-01-04             NaN             NaN             NaN             NaN
# 2013-01-05     3232.153651             NaN             NaN             NaN
# 2013-01-06     3272.932430     3232.153651             NaN             NaN
# 2013-01-07     3160.668542     3272.932430     3232.153651             NaN
#
# [7 rows x 24 columns]

# %%
daily_n.dropna(inplace=True)

# %% [markdown]
# Decomposition

# %%
decomposition = seasonal_decompose(daily_n['Peak Day Value'], model='additive')

plt.figure(figsize=(12, 8))
plt.subplot(4, 1, 1)
plt.plot(decomposition.trend)
plt.title('Trend')
plt.xlabel('Date')
plt.ylabel('Trend Value')

plt.subplot(4, 1, 2)
plt.plot(decomposition.seasonal)
plt.title('Seasonality')
plt.xlabel('Date')
plt.ylabel('Seasonal Value')

plt.subplot(4, 1, 3)
plt.plot(decomposition.resid)
plt.title('Residuals')
plt.xlabel('Date')
plt.ylabel('Residual Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# Differencing

# %%
#Augmented Dickey-Fuller test to check for stationarity before differencing
result_before_diff = adfuller(daily_n['Peak Day Value'].dropna())
print('ADF Statistic before differencing:', result_before_diff[0])
print('p-value before differencing:', result_before_diff[1])

#Differencing to make the time series stationary
stationary_peak_day_value = daily_n['Peak Day Value'].diff().dropna()

#Augmented Dickey-Fuller test again to check for stationarity after differencing
result_after_diff = adfuller(stationary_peak_day_value)
print('ADF Statistic after differencing:', result_after_diff[0])
print('p-value after differencing:', result_after_diff[1])

plt.figure(figsize=(12, 6))
plt.plot(daily_n.index[:-1], daily_n['Peak Day Value'].values[:-1], label='Original Time Series')
plt.plot(daily_n.index[1:], stationary_peak_day_value.values, label='Stationary Time Series')
plt.xlabel('Date')
plt.ylabel('Peak Day Value (kWh)')
plt.title('Original and Stationary Time Series')
plt.legend()
plt.show()
# Out:
# ADF Statistic before differencing: -1.8891854824751213
# p-value before differencing: 0.3371655785508538
# ADF Statistic after differencing: -4.39766325167437
# p-value after differencing: 0.0002996719183393718

# %% [markdown]
# ACF and PACF

# %%
#ACF and PACF before differencing
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plot_acf(daily_n['Peak Day Value'].dropna(), lags=40, ax=plt.gca(), title='ACF (Original Time Series)')

plt.subplot(2, 1, 2)
plot_pacf(daily_n['Peak Day Value'].dropna(), lags=40, ax=plt.gca(), title='PACF (Original Time Series)')

plt.tight_layout()
plt.show()

#ACF and PACF after differencing
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plot_acf(stationary_peak_day_value, lags=40, ax=plt.gca(), title='ACF (Stationary Time Series)')

plt.subplot(2, 1, 2)
plot_pacf(stationary_peak_day_value, lags=40, ax=plt.gca(), title='PACF (Stationary Time Series)')

plt.tight_layout()
plt.show()

# %% [markdown]
# SARIMAX Rolling Forecasts

# %% [markdown]
# Feature Selection

# %%
daily_n = daily_n.drop(columns=["Daily Mean Windspeed (kn)"])

# %% [markdown]
# Train/Test Data

# %%
end_of_october = daily_n.index.get_loc('2013-10-31')

# %%
train_data = daily_n.iloc[:end_of_october+1]
test_data = daily_n.iloc[end_of_october+1:]

# %%
#Exogenous variables
exog_train = train_data.drop(columns=['Peak Day Value', 'Peak Day Hour',])
exog_test = test_data.drop(columns=['Peak Day Value', 'Peak Day Hour'])

# %% [markdown]
# Best Parameters

# %%
#Using auto_arima to find best SARIMAX parameters
best_params = auto_arima(train_data['Peak Day Value'], exogenous=exog_train, seasonal=True, m=7,
                          trace=True, suppress_warnings=True, stepwise=True, max_order=None)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=2.60 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=3647.116, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=3625.991, Time=0.40 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=3634.025, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=3645.193, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=3648.778, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=3608.889, Time=0.86 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=3576.790, Time=1.56 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=3574.898, Time=0.90 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=3634.343, Time=0.27 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=3576.801, Time=1.94 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=3622.095, Time=0.76 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=3576.207, Time=1.27 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=3574.491, Time=0.89 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=3625.544, Time=0.32 sec
#  ARIMA(0,1,1)(2,0,1)[7] intercept   : AIC=3576.356, Time=1.74 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=3576.364, Time=2.12 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=3648.644, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,2)[7] intercept   : AIC=3621.493, Time=0.92 sec
#  ARIMA(0,1,1)(2,0,0)[7] intercept   : AIC=3608.135, Time=0.79 sec
#  ARIMA(0,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=3575.219, Time=1.39 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=3578.413, Time=1.65 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=3572.494, Time=0.97 sec
#  ARIMA(0,1,1)(0,0,1)[7]             : AIC=3632.067, Time=0.26 sec
#  ARIMA(0,1,1)(1,0,0)[7]             : AIC=3623.568, Time=0.16 sec
#  ARIMA(0,1,1)(2,0,1)[7]             : AIC=inf, Time=0.76 sec
#  ARIMA(0,1,1)(1,0,2)[7]             : AIC=3574.365, Time=1.65 sec
#  ARIMA(0,1,1)(0,0,0)[7]             : AIC=3646.727, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,2)[7]             : AIC=3619.510, Time=0.38 sec
#  ARIMA(0,1,1)(2,0,0)[7]             : AIC=3606.137, Time=0.24 sec
#  ARIMA(0,1,1)(2,0,2)[7]             : AIC=3576.488, Time=2.64 sec
#  ARIMA(0,1,0)(1,0,1)[7]             : AIC=inf, Time=0.30 sec
#  ARIMA(1,1,1)(1,0,1)[7]             : AIC=inf, Time=0.73 sec
#  ARIMA(0,1,2)(1,0,1)[7]             : AIC=inf, Time=0.60 sec
#  ARIMA(1,1,0)(1,0,1)[7]             : AIC=3572.902, Time=0.57 sec
#  ARIMA(1,1,2)(1,0,1)[7]             : AIC=3569.093, Time=1.44 sec
#  ARIMA(1,1,2)(0,0,1)[7]             : AIC=3620.045, Time=0.26 sec
#  ARIMA(1,1,2)(1,0,0)[7]             : AIC=3612.818, Time=0.38 sec
#  ARIMA(1,1,2)(2,0,1)[7]             : AIC=3570.834, Time=1.77 sec
#  ARIMA(1,1,2)(1,0,2)[7]             : AIC=3570.842, Time=2.11 sec
#  ARIMA(1,1,2)(0,0,0)[7]             : AIC=3630.885, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,2)[7]             : AIC=3608.995, Time=0.72 sec
#  ARIMA(1,1,2)(2,0,0)[7]             : AIC=3596.474, Time=0.59 sec
#  ARIMA(1,1,2)(2,0,2)[7]             : AIC=3572.768, Time=2.21 sec
#  ARIMA(2,1,2)(1,0,1)[7]             : AIC=inf, Time=0.82 sec
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=inf, Time=1.44 sec
#  ARIMA(0,1,3)(1,0,1)[7]             : AIC=3573.179, Time=1.42 sec
#  ARIMA(2,1,1)(1,0,1)[7]             : AIC=3569.086, Time=1.36 sec
#  ARIMA(2,1,1)(0,0,1)[7]             : AIC=3619.778, Time=0.33 sec
#  ARIMA(2,1,1)(1,0,0)[7]             : AIC=3612.743, Time=0.32 sec
#  ARIMA(2,1,1)(2,0,1)[7]             : AIC=3570.953, Time=2.54 sec
#  ARIMA(2,1,1)(1,0,2)[7]             : AIC=3570.848, Time=2.85 sec
#  ARIMA(2,1,1)(0,0,0)[7]             : AIC=3629.809, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,2)[7]             : AIC=3608.928, Time=1.15 sec
#  ARIMA(2,1,1)(2,0,0)[7]             : AIC=3596.472, Time=1.07 sec
#  ARIMA(2,1,1)(2,0,2)[7]             : AIC=3572.768, Time=2.29 sec
#  ARIMA(2,1,0)(1,0,1)[7]             : AIC=3574.211, Time=1.04 sec
#  ARIMA(3,1,1)(1,0,1)[7]             : AIC=3570.391, Time=1.35 sec
#  ARIMA(3,1,0)(1,0,1)[7]             : AIC=inf, Time=0.80 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=3573.147, Time=1.75 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.51 sec
#
# Best model:  ARIMA(2,1,1)(1,0,1)[7]
# Total fit time: 66.968 seconds

# %%
print(best_params.summary())
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  297
# Model:             SARIMAX(2, 1, 1)x(1, 0, 1, 7)   Log Likelihood               -1778.543
# Date:                           Fri, 25 Aug 2023   AIC                           3569.086
# Time:                                   17:37:50   BIC                           3591.228
# Sample:                               01-08-2013   HQIC                          3577.951
#                                     - 10-31-2013
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7075      0.095      7.411      0.000       0.520       0.895
# ar.L2          0.0052      0.060      0.085      0.932      -0.113       0.124
# ma.L1         -0.8590      0.086     -9.954      0.000      -1.028      -0.690
# ar.S.L7        0.9870      0.011     87.661      0.000       0.965       1.009
# ma.S.L7       -0.8946      0.047    -19.109      0.000      -0.986      -0.803
# sigma2      9416.9056    627.424     15.009      0.000    8187.177    1.06e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                20.30
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.39   Skew:                            -0.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Rolling Forecasts

# %%
#Rolling forecast
rolling_forecast = []
rolling_conf_int = []

for t in range(len(test_data)):
    train_data = train_data.reset_index(drop=True)
    exog_train = exog_train.reset_index(drop=True)

    model = SARIMAX(train_data['Peak Day Value'],
                    exog=exog_train,
                    order=best_params.order,
                    seasonal_order=best_params.seasonal_order)
    results = model.fit(disp=False)

    forecast_obj = results.get_forecast(steps=1, exog=exog_test.iloc[[t]])
    forecast = forecast_obj.predicted_mean.iloc[0]
    conf_int = forecast_obj.conf_int().iloc[0]

    #Appending to rolling forecast lists
    rolling_forecast.append(forecast)
    rolling_conf_int.append(conf_int)

    #Adding test data to training data for the next loop
    train_data = train_data.append(test_data.iloc[t])
    exog_train = exog_train.append(exog_test.iloc[[t]])
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-28-bb37a32348e2>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(test_data.iloc[t])
# <ipython-input-28-bb37a32348e2>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exog_train = exog_train.append(exog_test.iloc[[t]])

# %% [markdown]
# Performance Metrics

# %%
#Calculating error metrics for the rolling forecast
mae = mean_absolute_error(test_data['Peak Day Value'], rolling_forecast)
mape = np.mean(np.abs((test_data['Peak Day Value'] - rolling_forecast) / test_data['Peak Day Value'])) * 100

print(f'Rolling Forecast MAE: {mae}')
print(f'Rolling Forecast MAPE: {mape}%')
# Out:
# Rolling Forecast MAE: 37.31933606216
# Rolling Forecast MAPE: 1.2261332668077758%

# %% [markdown]
# Plot

# %%
rolling_forecast_series = pd.Series(rolling_forecast, index=test_data.index)

#Actual vs forecasted values
plt.figure(figsize=(12, 6))
plt.plot(test_data.index, test_data['Peak Day Value'], label="Actual Values", color='blue')
plt.plot(test_data.index, rolling_forecast_series, label="Rolling Forecast", color='red')
plt.fill_between(test_data.index,
                 [i[0] for i in rolling_conf_int],
                 [i[1] for i in rolling_conf_int],
                 color='pink', alpha=0.3, label="95% Confidence Interval")
plt.legend(loc='best')
plt.title("Actual vs Rolling Forecast Peak Day Values (N)")

plt.xlabel("Date")
plt.ylabel("Peak Day Value (N)")

textstr = f'MAE: {mae:.2f}\nMAPE: {mape:.2f}%'
props = dict(boxstyle='round, pad=0.5', facecolor='white', edgecolor='gray', alpha=0.7)

plt.text(0.05, 0.95, textstr, transform=plt.gca().transAxes, verticalalignment='top', bbox=props)

plt.show()

# %%
results_df = pd.DataFrame({
    'Date': test_data.index[:61],
    'Actual': test_data['Peak Day Value'].values[:61],
    'Predicted': rolling_forecast[:61]
})

results_df['Actual'] = results_df['Actual'].apply(lambda x: '{:.2f}'.format(x))
results_df['Predicted'] = results_df['Predicted'].apply(lambda x: '{:.2f}'.format(x))

results_df['Difference (%)'] = ((results_df['Predicted'].astype(float) - results_df['Actual'].astype(float)) / results_df['Actual'].astype(float)) * 100

results_df['Difference (%)'] = results_df['Difference (%)'].apply(lambda x: '{:.2f}%'.format(x))

print(results_df)

total_actual_value = results_df['Actual'].astype(float).sum()
total_predicted_value = results_df['Predicted'].astype(float).sum()

total_difference_value = total_predicted_value - total_actual_value
total_difference_percentage_value = (total_difference_value / total_actual_value) * 100

print("\nTotal Actual Value:", total_actual_value)
print("Total Predicted Value:", total_predicted_value)
print("Total Difference:", total_difference_value)
print("Total Difference Percentage: {:.2f}%".format(total_difference_percentage_value))
# Out:
#          Date   Actual Predicted Difference (%)
# 0  2013-11-01  2697.88   2706.13          0.31%
# 1  2013-11-02  2718.94   2685.64         -1.22%
# 2  2013-11-03  2997.60   2928.42         -2.31%
# 3  2013-11-04  2976.29   2988.90          0.42%
# 4  2013-11-05  2987.40   2999.30          0.40%
# ..        ...      ...       ...            ...
# 56 2013-12-27  2936.76   2945.72          0.31%
# 57 2013-12-28  2933.94   2854.39         -2.71%
# 58 2013-12-29  3083.52   3002.46         -2.63%
# 59 2013-12-30  3064.23   3131.87          2.21%
# 60 2013-12-31  3185.08   3083.37         -3.19%
#
# [61 rows x 4 columns]
#
# Total Actual Value: 185633.56999999998
# Total Predicted Value: 185908.62000000002
# Total Difference: 275.05000000004657
# Total Difference Percentage: 0.15%

# %% [markdown]
# Model Diagnostics

# %%
fig = best_params.plot_diagnostics(figsize=(15,12))

ax = fig.axes[0]
ax.set_xlabel('Date')
ax.set_ylabel('Standardized Residuals')

ax = fig.axes[1]
ax.set_xlabel('Standardized Residual Value')
ax.set_ylabel('Frequency')

ax = fig.axes[2]
ax.set_xlabel('Theoretical Quantiles')
ax.set_ylabel('Standardized Residuals')

ax = fig.axes[3]
ax.set_xlabel('Lag')
ax.set_ylabel('Autocorrelation')

plt.show()
