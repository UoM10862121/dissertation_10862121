# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.29.36)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import json
from datetime import timedelta
from sklearn.ensemble import RandomForestRegressor
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima
import pickle
import itertools
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pmdarima as pm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
merged_d = pd.read_csv(r'/content/drive/MyDrive/Dissertation_10862121/merged_d.csv')

# %%
merged_d['GMT'] = pd.to_datetime(merged_d['GMT'])
merged_d['Date'] = pd.to_datetime(merged_d['Date'])
merged_d.set_index('GMT', inplace=True)

# %%
merged_d
# Out:
#                      Total Household Consumption (D)       Date      Time  \
# GMT
# 2013-01-01 00:00:00                       393.709000 2013-01-01  00:00:00
# 2013-01-01 01:00:00                       327.556000 2013-01-01  01:00:00
# 2013-01-01 02:00:00                       286.207000 2013-01-01  02:00:00
# 2013-01-01 03:00:00                       250.964000 2013-01-01  03:00:00
# 2013-01-01 04:00:00                       233.412000 2013-01-01  04:00:00
# ...                                              ...        ...       ...
# 2013-12-31 19:00:00                       743.251693 2013-12-31  19:00:00
# 2013-12-31 20:00:00                       645.912531 2013-12-31  20:00:00
# 2013-12-31 21:00:00                       586.851605 2013-12-31  21:00:00
# 2013-12-31 22:00:00                       508.774572 2013-12-31  22:00:00
# 2013-12-31 23:00:00                       453.855276 2013-12-31  23:00:00
#
#                      Year  Month  Day  Hour  DayOfWeek  IsHoliday  \
# GMT
# 2013-01-01 00:00:00  2013      1    1     0          1       True
# 2013-01-01 01:00:00  2013      1    1     1          1       True
# 2013-01-01 02:00:00  2013      1    1     2          1       True
# 2013-01-01 03:00:00  2013      1    1     3          1       True
# 2013-01-01 04:00:00  2013      1    1     4          1       True
# ...                   ...    ...  ...   ...        ...        ...
# 2013-12-31 19:00:00  2013     12   31    19          1      False
# 2013-12-31 20:00:00  2013     12   31    20          1      False
# 2013-12-31 21:00:00  2013     12   31    21          1      False
# 2013-12-31 22:00:00  2013     12   31    22          1      False
# 2013-12-31 23:00:00  2013     12   31    23          1      False
#
#                      Hourly Global Radiation (KJ/m2)  ...  \
# GMT                                                   ...
# 2013-01-01 00:00:00                              0.0  ...
# 2013-01-01 01:00:00                              0.0  ...
# 2013-01-01 02:00:00                              0.0  ...
# 2013-01-01 03:00:00                              0.0  ...
# 2013-01-01 04:00:00                              0.0  ...
# ...                                              ...  ...
# 2013-12-31 19:00:00                              0.0  ...
# 2013-12-31 20:00:00                              0.0  ...
# 2013-12-31 21:00:00                              0.0  ...
# 2013-12-31 22:00:00                              0.0  ...
# 2013-12-31 23:00:00                              0.0  ...
#
#                      Hourly Pressure at Mean Sea Level (hPa)  \
# GMT
# 2013-01-01 00:00:00                                  999.400
# 2013-01-01 01:00:00                                  999.675
# 2013-01-01 02:00:00                                  999.975
# 2013-01-01 03:00:00                                 1000.725
# 2013-01-01 04:00:00                                 1001.300
# ...                                                      ...
# 2013-12-31 19:00:00                                 1002.900
# 2013-12-31 20:00:00                                 1003.175
# 2013-12-31 21:00:00                                 1003.450
# 2013-12-31 22:00:00                                 1002.925
# 2013-12-31 23:00:00                                 1002.725
#
#                      Hourly Rainfall Total (mm)  Hourly Relative Humidity (%)  \
# GMT
# 2013-01-01 00:00:00                        0.00                     92.085714
# 2013-01-01 01:00:00                        0.00                     91.042857
# 2013-01-01 02:00:00                        0.20                     92.685714
# 2013-01-01 03:00:00                        0.96                     89.871429
# 2013-01-01 04:00:00                        0.08                     88.585714
# ...                                         ...                           ...
# 2013-12-31 19:00:00                        0.00                     85.385714
# 2013-12-31 20:00:00                        0.00                     84.442857
# 2013-12-31 21:00:00                        0.00                     83.257143
# 2013-12-31 22:00:00                        0.00                     88.628571
# 2013-12-31 23:00:00                        0.00                     88.314286
#
#                      Hourly Snow Depth (cm)  Hourly Temperature (C)  \
# GMT
# 2013-01-01 00:00:00                     0.0                8.914286
# 2013-01-01 01:00:00                     0.0                8.785714
# 2013-01-01 02:00:00                     0.0                8.514286
# 2013-01-01 03:00:00                     0.0                7.285714
# 2013-01-01 04:00:00                     0.0                6.700000
# ...                                     ...                     ...
# 2013-12-31 19:00:00                     0.0                5.942857
# 2013-12-31 20:00:00                     0.0                5.442857
# 2013-12-31 21:00:00                     0.0                5.414286
# 2013-12-31 22:00:00                     0.0                5.971429
# 2013-12-31 23:00:00                     0.0                7.057143
#
#                      Hourly Total Cloud Cover (oktas)\n  \
# GMT
# 2013-01-01 00:00:00                            8.000000
# 2013-01-01 01:00:00                            8.000000
# 2013-01-01 02:00:00                            8.000000
# 2013-01-01 03:00:00                            7.666667
# 2013-01-01 04:00:00                            4.000000
# ...                                                 ...
# 2013-12-31 19:00:00                            6.333333
# 2013-12-31 20:00:00                            1.333333
# 2013-12-31 21:00:00                            1.000000
# 2013-12-31 22:00:00                            2.333333
# 2013-12-31 23:00:00                            6.333333
#
#                      Hourly Visibility (dm)  Low  Default  High
# GMT
# 2013-01-01 00:00:00             2133.333333    0        1     0
# 2013-01-01 01:00:00             1766.666667    0        1     0
# 2013-01-01 02:00:00             1333.333333    0        1     0
# 2013-01-01 03:00:00             4100.000000    0        1     0
# 2013-01-01 04:00:00             5500.000000    0        1     0
# ...                                     ...  ...      ...   ...
# 2013-12-31 19:00:00             3666.666667    0        1     0
# 2013-12-31 20:00:00             4000.000000    0        1     0
# 2013-12-31 21:00:00             3833.333333    0        1     0
# 2013-12-31 22:00:00             2266.666667    0        1     0
# 2013-12-31 23:00:00             2200.000000    0        1     0
#
# [8760 rows x 23 columns]

# %% [markdown]
# Daily Dataframe

# %%
#New DataFrame storing daily aggregated data
daily_d = merged_d.resample('D').agg({
    'Total Household Consumption (D)': 'sum',
    'Hourly Temperature (C)': 'mean',
    'Hourly Pressure at Mean Sea Level (hPa)': 'mean',
    'Hourly Global Radiation (KJ/m2)': 'mean',
    'Hourly Rainfall Total (mm)': 'mean',
    'Hourly Mean Wind Direction (o)': 'mean',
    'Hourly Mean Windspeed (kn)': 'mean',
    'Hourly Maximum Gust (kn)': 'mean',
    'Hourly Visibility (dm)': 'mean',
    'Hourly Relative Humidity (%)': 'mean',
    'Hourly Total Cloud Cover (oktas)\n': 'mean',
}).reset_index()

# %%
#Non-aggregated columns
daily_d['Date'] = daily_d['GMT'].dt.date
daily_d['Month'] = daily_d['GMT'].dt.month
daily_d['Day'] = daily_d['GMT'].dt.day
daily_d['DayOfWeek'] = daily_d['GMT'].dt.dayofweek

# %%
#Renaming the columns for the weather variables to indicate they now contain daily averages
daily_d.rename(columns={
    'Hourly Temperature (C)': 'Daily Temperature (C)',
    'Hourly Pressure at Mean Sea Level (hPa)': 'Daily Pressure at Mean Sea Level (hPa)',
    'Hourly Global Radiation (KJ/m2)': 'Daily Global Radiation (KJ/m2)',
    'Hourly Rainfall Total (mm)': 'Daily Rainfall Total (mm)',
    'Hourly Mean Wind Direction (o)': 'Daily Mean Wind Direction (o)',
    'Hourly Mean Windspeed (kn)': 'Daily Mean Windspeed (kn)',
    'Hourly Maximum Gust (kn)': 'Daily Maximum Gust (kn)',
    'Hourly Visibility (dm)': 'Daily Visibility (dm)',
    'Hourly Relative Humidity (%)': 'Daily Relative Humidity (%)',
    'Hourly Total Cloud Cover (oktas)\n': 'Daily Total Cloud Cover (oktas)'
}, inplace=True)

# %%
#Calculating 'Peak Day Value' and 'Peak Day Hour'
max_consumption_idx = merged_d.groupby(merged_d.index.date)['Total Household Consumption (D)'].idxmax()
peak_values = merged_d.loc[max_consumption_idx, 'Total Household Consumption (D)']
peak_hours = merged_d.loc[max_consumption_idx, 'Hour']

# %%
#Creating dictionaries for mapping
peak_values_dict = dict(zip(peak_values.index.date, peak_values.values))
peak_hours_dict = dict(zip(peak_hours.index.date, peak_hours.values))

#Merging 'Peak Day Value' and 'Peak Day Hour' into the daily_aggregated DataFrame
daily_d['Peak Day Value'] = daily_d['Date'].map(peak_values_dict)
daily_d['Peak Day Hour'] = daily_d['Date'].map(peak_hours_dict)

# %%
daily_d.drop(columns=['GMT'], inplace=True)

# %%
daily_d['Date'] = pd.to_datetime(daily_d['Date'])
daily_d.set_index('Date', inplace=True)

# %%
#Converting the 'IsHoliday' column in merged_n to integer type for summation
merged_d['IsHoliday'] = merged_d['IsHoliday'].astype(int)

#Grouping by 'Date' and summing the 'IsHoliday' column
daily_holidays = merged_d.groupby('Date').agg({'IsHoliday': 'sum'})

#Converting the summed values to a binary (0 or 1) indicating presence of holiday
daily_holidays['IsHoliday'] = daily_holidays['IsHoliday'].apply(lambda x: 1 if x > 0 else 0)

daily_d['IsHoliday'] = daily_d.index.map(daily_holidays['IsHoliday']).fillna(0).astype(int)

# %%
daily_d
# Out:
#             Total Household Consumption (D)  Daily Temperature (C)  \
# Date
# 2013-01-01                     11389.871000               5.991667
# 2013-01-02                     11555.369000               6.440476
# 2013-01-03                     11010.191000              10.262500
# 2013-01-04                     11320.812000               9.350595
# 2013-01-05                     11125.943000               8.830952
# ...                                     ...                    ...
# 2013-12-27                     11310.611347               8.875595
# 2013-12-28                     10747.984432               5.114881
# 2013-12-29                     11502.317654               3.575000
# 2013-12-30                     11359.554728               8.364286
# 2013-12-31                     11526.596173               7.648214
#
#             Daily Pressure at Mean Sea Level (hPa)  \
# Date
# 2013-01-01                             1007.663542
# 2013-01-02                             1023.133333
# 2013-01-03                             1032.562500
# 2013-01-04                             1037.157292
# 2013-01-05                             1035.168750
# ...                                            ...
# 2013-12-27                              987.026042
# 2013-12-28                              997.500000
# 2013-12-29                             1014.921875
# 2013-12-30                             1011.072917
# 2013-12-31                             1004.409375
#
#             Daily Global Radiation (KJ/m2)  Daily Rainfall Total (mm)  \
# Date
# 2013-01-01                      169.819444                   0.053056
# 2013-01-02                       42.569444                   0.022083
# 2013-01-03                       73.277778                   0.000000
# 2013-01-04                       76.111111                   0.001389
# 2013-01-05                       52.430556                   0.000000
# ...                                    ...                        ...
# 2013-12-27                       51.805556                   0.201111
# 2013-12-28                      139.125000                   0.000000
# 2013-12-29                      177.194444                   0.009722
# 2013-12-30                       52.722222                   0.260972
# 2013-12-31                       37.819444                   0.233194
#
#             Daily Mean Wind Direction (o)  Daily Mean Windspeed (kn)  \
# Date
# 2013-01-01                     261.166667                   8.700000
# 2013-01-02                     237.750000                   7.083333
# 2013-01-03                     257.666667                   8.525000
# 2013-01-04                     266.500000                   8.466667
# 2013-01-05                     244.916667                   6.508333
# ...                                   ...                        ...
# 2013-12-27                     213.416667                  15.400000
# 2013-12-28                     229.916667                   6.158333
# 2013-12-29                     232.000000                   6.266667
# 2013-12-30                     200.416667                  13.400000
# 2013-12-31                     182.333333                   9.208333
#
#             Daily Maximum Gust (kn)  Daily Visibility (dm)  \
# Date
# 2013-01-01                15.141667            3816.666667
# 2013-01-02                11.925000            2337.638889
# 2013-01-03                14.816667            2503.611111
# 2013-01-04                14.875000            2924.444444
# 2013-01-05                11.458333            2072.361111
# ...                             ...                    ...
# 2013-12-27                28.516667            1995.972222
# 2013-12-28                10.891667            3338.888889
# 2013-12-29                10.800000            2831.944444
# 2013-12-30                24.466667            2367.083333
# 2013-12-31                17.408333            2581.527778
#
#             Daily Relative Humidity (%)  Daily Total Cloud Cover (oktas)  \
# Date
# 2013-01-01                    81.655952                         3.097222
# 2013-01-02                    91.691667                         6.722222
# 2013-01-03                    92.282738                         7.611111
# 2013-01-04                    85.682738                         7.777778
# 2013-01-05                    92.425000                         7.041667
# ...                                 ...                              ...
# 2013-12-27                    75.789286                         5.013889
# 2013-12-28                    78.417262                         2.847222
# 2013-12-29                    84.811905                         0.916667
# 2013-12-30                    84.788095                         5.125000
# 2013-12-31                    87.792262                         6.083333
#
#             Month  Day  DayOfWeek  Peak Day Value  Peak Day Hour  IsHoliday
# Date
# 2013-01-01      1    1          1      776.241000             18          1
# 2013-01-02      1    2          2      788.050000             18          0
# 2013-01-03      1    3          3      780.390000             18          0
# 2013-01-04      1    4          4      764.900000             18          0
# 2013-01-05      1    5          5      775.334000             18          0
# ...           ...  ...        ...             ...            ...        ...
# 2013-12-27     12   27          4      723.673711             18          0
# 2013-12-28     12   28          5      700.317915             18          0
# 2013-12-29     12   29          6      743.679319             18          0
# 2013-12-30     12   30          0      737.357275             18          0
# 2013-12-31     12   31          1      769.529073             18          0
#
# [365 rows x 17 columns]

# %% [markdown]
# Lags (Endogenous Variables)

# %%
daily_d['lag_1_day_peak'] = daily_d['Peak Day Value'].shift(1)
daily_d['lag_2_day_peak'] = daily_d['Peak Day Value'].shift(2)
daily_d['lag_3_day_peak'] = daily_d['Peak Day Value'].shift(3)
daily_d['lag_4_day_peak'] = daily_d['Peak Day Value'].shift(4)
daily_d['lag_5_day_peak'] = daily_d['Peak Day Value'].shift(5)
daily_d['lag_6_day_peak'] = daily_d['Peak Day Value'].shift(6)
daily_d['lag_7_day_peak'] = daily_d['Peak Day Value'].shift(7)

# %%
nan_rows = daily_d[daily_d.isna().any(axis=1)]
print(nan_rows)
# Out:
#             Total Household Consumption (D)  Daily Temperature (C)  \
# Date
# 2013-01-01                     11389.871000               5.991667
# 2013-01-02                     11555.369000               6.440476
# 2013-01-03                     11010.191000              10.262500
# 2013-01-04                     11320.812000               9.350595
# 2013-01-05                     11125.943000               8.830952
# 2013-01-06                     11817.219630               7.158929
# 2013-01-07                     11061.742111               7.730952
#
#             Daily Pressure at Mean Sea Level (hPa)  \
# Date
# 2013-01-01                             1007.663542
# 2013-01-02                             1023.133333
# 2013-01-03                             1032.562500
# 2013-01-04                             1037.157292
# 2013-01-05                             1035.168750
# 2013-01-06                             1032.208333
# 2013-01-07                             1026.888542
#
#             Daily Global Radiation (KJ/m2)  Daily Rainfall Total (mm)  \
# Date
# 2013-01-01                      169.819444                   0.053056
# 2013-01-02                       42.569444                   0.022083
# 2013-01-03                       73.277778                   0.000000
# 2013-01-04                       76.111111                   0.001389
# 2013-01-05                       52.430556                   0.000000
# 2013-01-06                       52.388889                   0.008611
# 2013-01-07                       37.694444                   0.001389
#
#             Daily Mean Wind Direction (o)  Daily Mean Windspeed (kn)  \
# Date
# 2013-01-01                     261.166667                   8.700000
# 2013-01-02                     237.750000                   7.083333
# 2013-01-03                     257.666667                   8.525000
# 2013-01-04                     266.500000                   8.466667
# 2013-01-05                     244.916667                   6.508333
# 2013-01-06                     223.666667                   4.258333
# 2013-01-07                     205.166667                   6.491667
#
#             Daily Maximum Gust (kn)  Daily Visibility (dm)  \
# Date
# 2013-01-01                15.141667            3816.666667
# 2013-01-02                11.925000            2337.638889
# 2013-01-03                14.816667            2503.611111
# 2013-01-04                14.875000            2924.444444
# 2013-01-05                11.458333            2072.361111
# 2013-01-06                 7.900000             623.194444
# 2013-01-07                11.450000            1270.555556
#
#             Daily Relative Humidity (%)  ...  Peak Day Value  Peak Day Hour  \
# Date                                     ...
# 2013-01-01                    81.655952  ...         776.241             18
# 2013-01-02                    91.691667  ...         788.050             18
# 2013-01-03                    92.282738  ...         780.390             18
# 2013-01-04                    85.682738  ...         764.900             18
# 2013-01-05                    92.425000  ...         775.334             18
# 2013-01-06                    97.227976  ...         803.541             18
# 2013-01-07                    92.857143  ...         780.121             18
#
#             IsHoliday  lag_1_day_peak  lag_2_day_peak  lag_3_day_peak  \
# Date
# 2013-01-01          1             NaN             NaN             NaN
# 2013-01-02          0         776.241             NaN             NaN
# 2013-01-03          0         788.050         776.241             NaN
# 2013-01-04          0         780.390         788.050         776.241
# 2013-01-05          0         764.900         780.390         788.050
# 2013-01-06          0         775.334         764.900         780.390
# 2013-01-07          0         803.541         775.334         764.900
#
#             lag_4_day_peak  lag_5_day_peak  lag_6_day_peak  lag_7_day_peak
# Date
# 2013-01-01             NaN             NaN             NaN             NaN
# 2013-01-02             NaN             NaN             NaN             NaN
# 2013-01-03             NaN             NaN             NaN             NaN
# 2013-01-04             NaN             NaN             NaN             NaN
# 2013-01-05         776.241             NaN             NaN             NaN
# 2013-01-06         788.050         776.241             NaN             NaN
# 2013-01-07         780.390         788.050         776.241             NaN
#
# [7 rows x 24 columns]

# %%
daily_d.dropna(inplace=True)

# %% [markdown]
# Decomposition

# %%
decomposition = seasonal_decompose(daily_d['Peak Day Hour'], model='additive')

plt.figure(figsize=(12, 8))
plt.subplot(4, 1, 1)
plt.plot(decomposition.trend)
plt.title('Trend')

plt.subplot(4, 1, 2)
plt.plot(decomposition.seasonal)
plt.title('Seasonality')

plt.subplot(4, 1, 3)
plt.plot(decomposition.resid)
plt.title('Residuals')

plt.tight_layout()
plt.show()

# %% [markdown]
# Differencing

# %%
#Augmented Dickey-Fuller test to check for stationarity before differencing
result_before_diff = adfuller(daily_d['Peak Day Hour'].dropna())
print('ADF Statistic before differencing:', result_before_diff[0])
print('p-value before differencing:', result_before_diff[1])

#Differencing to make the time series stationary
stationary_peak_day_value = daily_d['Peak Day Hour'].diff().dropna()

#Augmented Dickey-Fuller test again to check for stationarity after differencing
result_after_diff = adfuller(stationary_peak_day_value)
print('ADF Statistic after differencing:', result_after_diff[0])
print('p-value after differencing:', result_after_diff[1])

plt.figure(figsize=(12, 6))
plt.plot(daily_d.index[:-1], daily_d['Peak Day Hour'].values[:-1], label='Original Time Series')
plt.plot(daily_d.index[1:], stationary_peak_day_value.values, label='Stationary Time Series')
plt.xlabel('Date')
plt.ylabel('Peak Day Hour')
plt.title('Original and Stationary Time Series')
plt.legend()
plt.show()
# Out:
# ADF Statistic before differencing: -2.9473492901385794
# p-value before differencing: 0.04011250062507201
# ADF Statistic after differencing: -8.59097699462587
# p-value after differencing: 7.28769859489193e-14

# %% [markdown]
# ACF and PACF

# %%
#ACF and PACF before differencing
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plot_acf(daily_d['Peak Day Hour'].dropna(), lags=40, ax=plt.gca(), title='ACF (Original Time Series)')

plt.subplot(2, 1, 2)
plot_pacf(daily_d['Peak Day Hour'].dropna(), lags=40, ax=plt.gca(), title='PACF (Original Time Series)')

plt.tight_layout()
plt.show()

#ACF and PACF after differencing
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plot_acf(stationary_peak_day_value, lags=40, ax=plt.gca(), title='ACF (Stationary Time Series)')

plt.subplot(2, 1, 2)
plot_pacf(stationary_peak_day_value, lags=40, ax=plt.gca(), title='PACF (Stationary Time Series)')

plt.tight_layout()
plt.show()

# %% [markdown]
# SARIMAX

# %% [markdown]
# Sine/Cosine

# %%
theta = (2 * np.pi * daily_d['Peak Day Hour']) / 24
daily_d['sine_hour'] = np.sin(theta)
daily_d['cosine_hour'] = np.cos(theta)

# %% [markdown]
# Feature Selection

# %%
daily_d = daily_d.drop(columns=["Daily Mean Windspeed (kn)"])

# %% [markdown]
# Train/Test Split

# %%
end_of_october = daily_d.index.get_loc('2013-10-31')

# %%
train_data = daily_d.iloc[:end_of_october+1]
test_data = daily_d.iloc[end_of_october+1:]

# %%
exog_train = train_data.drop(columns=['Peak Day Hour', 'sine_hour', 'cosine_hour'])
exog_test = test_data.drop(columns=['Peak Day Hour', 'sine_hour', 'cosine_hour'])

# %% [markdown]
# Best Parameters

# %%
#Best parameters for sine_hour
best_params_sine = auto_arima(train_data['sine_hour'], exogenous=exog_train, seasonal=True, m=7,
                              trace=True, suppress_warnings=True, stepwise=True, max_order=None)

#Best parameters for cosine_hour
best_params_cosine = auto_arima(train_data['cosine_hour'], exogenous=exog_train, seasonal=True, m=7,
                                trace=True, suppress_warnings=True, stepwise=True, max_order=None)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=-438.952, Time=2.15 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=-270.150, Time=0.07 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=-341.902, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=-446.868, Time=0.40 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=-272.150, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=-448.576, Time=0.15 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=-446.856, Time=0.67 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=-444.857, Time=0.61 sec
#  ARIMA(1,1,1)(0,0,0)[7] intercept   : AIC=-446.645, Time=0.38 sec
#  ARIMA(0,1,2)(0,0,0)[7] intercept   : AIC=-446.650, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=-343.709, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=-444.651, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,0)[7]             : AIC=-450.545, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[7]             : AIC=-448.825, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,1)[7]             : AIC=-448.836, Time=0.21 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=-447.093, Time=0.43 sec
#  ARIMA(1,1,1)(0,0,0)[7]             : AIC=-448.612, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[7]             : AIC=-448.617, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[7]             : AIC=-345.709, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[7]             : AIC=-446.619, Time=0.08 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[7]
# Total fit time: 6.339 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=-121.243, Time=2.06 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=41.331, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=-28.326, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=-125.053, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=39.331, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=-125.727, Time=0.12 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=-125.120, Time=0.78 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=-123.459, Time=1.53 sec
#  ARIMA(1,1,1)(0,0,0)[7] intercept   : AIC=-123.740, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,0)[7] intercept   : AIC=-123.743, Time=0.27 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=-28.616, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=-123.626, Time=0.51 sec
#  ARIMA(0,1,1)(0,0,0)[7]             : AIC=-127.691, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,0)[7]             : AIC=-127.082, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,1)[7]             : AIC=-127.015, Time=0.42 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=-125.425, Time=0.45 sec
#  ARIMA(1,1,1)(0,0,0)[7]             : AIC=-125.705, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[7]             : AIC=-125.708, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[7]             : AIC=-30.616, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[7]             : AIC=-125.587, Time=0.12 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[7]
# Total fit time: 7.896 seconds

# %%
print(best_params_sine.summary())
print(best_params_cosine.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                 227.272
# Date:                Fri, 25 Aug 2023   AIC                           -450.545
# Time:                        17:18:15   BIC                           -443.164
# Sample:                    01-08-2013   HQIC                          -447.589
#                          - 10-31-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9346      0.027    -35.168      0.000      -0.987      -0.883
# sigma2         0.0125      0.000     84.025      0.000       0.012       0.013
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):            122803.62
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.01   Skew:                             9.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                       101.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                  65.845
# Date:                Fri, 25 Aug 2023   AIC                           -127.691
# Time:                        17:18:15   BIC                           -120.310
# Sample:                    01-08-2013   HQIC                          -124.736
#                          - 10-31-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8736      0.033    -26.138      0.000      -0.939      -0.808
# sigma2         0.0373      0.002     24.875      0.000       0.034       0.040
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               959.80
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.42   Skew:                            -2.00
# Prob(H) (two-sided):                  0.08   Kurtosis:                        10.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Fit & Predict

# %%
model_sine = SARIMAX(train_data['sine_hour'], exog=exog_train, order=best_params_sine.order, seasonal_order=best_params_sine.seasonal_order)
results_sine = model_sine.fit(disp=False)
forecast_sine = results_sine.get_forecast(steps=61, exog=exog_test).predicted_mean
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_cosine = SARIMAX(train_data['cosine_hour'], exog=exog_train, order=best_params_cosine.order,seasonal_order=best_params_cosine.seasonal_order)
results_cosine = model_cosine.fit(disp=False)
forecast_cosine = results_cosine.get_forecast(steps=61, exog=exog_test).predicted_mean
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#Converting sine and cosine forecasts back to hour format
predicted_hours = [np.arctan2(sin_val, cos_val) * (12/np.pi) for sin_val, cos_val in zip(forecast_sine, forecast_cosine)]
predicted_hours = [round(hour) if hour >= 0 else round(hour + 24) for hour in predicted_hours]

# %% [markdown]
# Performance Metrics

# %%
#MAE and MAPE
mae = mean_absolute_error(test_data['Peak Day Hour'], predicted_hours)
mape = np.mean(np.abs((test_data['Peak Day Hour'] - predicted_hours) / test_data['Peak Day Hour'])) * 100

print(f"Forecast MAE: {mae}")
print(f"Forecast MAPE: {mape}%")
# Out:
# Forecast MAE: 1.1147540983606556
# Forecast MAPE: 6.304432792784819%

# %% [markdown]
# Plot

# %%
plt.figure(figsize=(12, 6))
plt.plot(test_data.index, test_data['Peak Day Hour'], label="Actual Hours", color='blue')
plt.plot(test_data.index, predicted_hours, label="Predicted Hours", color='red')
plt.legend(loc='best')
plt.title("Actual vs Predicted Peak Day Hours (D)")

plt.xlabel("Date")
plt.ylabel("Hour")

textstr = f'MAE: {mae:.2f}\nMAPE: {mape:.2f}%'
props = dict(boxstyle='round, pad=0.5', facecolor='white', edgecolor='gray', alpha=0.7)

plt.text(0.05, 0.05, textstr, transform=plt.gca().transAxes, verticalalignment='bottom', bbox=props)

plt.show()

# %%
results_df = pd.DataFrame({
    'Date': test_data.index[:61],
    'Actual Hour': test_data['Peak Day Hour'].values[:61],
    'Predicted Hour': predicted_hours[:61]
})

results_df['Actual Hour'] = results_df['Actual Hour'].apply(lambda x: '{:.2f}'.format(x))
results_df['Predicted Hour'] = results_df['Predicted Hour'].apply(lambda x: '{:.2f}'.format(x))

results_df['Difference (%)'] = ((results_df['Predicted Hour'].astype(float) - results_df['Actual Hour'].astype(float)) / results_df['Actual Hour'].astype(float)) * 100

results_df['Difference (%)'] = results_df['Difference (%)'].apply(lambda x: '{:.2f}%'.format(x))

print(results_df)
# Out:
#          Date Actual Hour Predicted Hour Difference (%)
# 0  2013-11-01       18.00          18.00          0.00%
# 1  2013-11-02       18.00          18.00          0.00%
# 2  2013-11-03       18.00          17.00         -5.56%
# 3  2013-11-04       18.00          18.00          0.00%
# 4  2013-11-05       18.00          17.00         -5.56%
# ..        ...         ...            ...            ...
# 56 2013-12-27       18.00          16.00        -11.11%
# 57 2013-12-28       18.00          17.00         -5.56%
# 58 2013-12-29       18.00          17.00         -5.56%
# 59 2013-12-30       18.00          16.00        -11.11%
# 60 2013-12-31       18.00          16.00        -11.11%
#
# [61 rows x 4 columns]
